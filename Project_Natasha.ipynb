# %% [markdown]
# <a href="https://colab.research.google.com/github/khanittha-phusopha/DWDM21/blob/main/Project_Natasha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Project Natasha
# -แสดงวิธีการโหลด
#
# -ความเชื่อมโยงของ 3 ตาราง
#
# **1** การนำเข้าปุ๋ยเคมี (รายประเทศ)\
# องค์กร : ศูนย์เทคโนโลยีสารสนเทศและการสื่อสาร กรมวิชาการเกษตร
# จาก : https://data.go.th
#
# **2** การนำเข้าเมล็ดพันธุ์ควบคุม (รายประเทศ)\
# องค์กร : ศูนย์เทคโนโลยีสารสนเทศและการสื่อสาร กรมวิชาการเกษตร
# จาก : https://data.go.th
#
# **3** สารป้องกันและกำจัดโรคพืชที่มีปริมาณการนำเข้าสูง\
# องค์กร : ศูนย์เทคโนโลยีสารสนเทศและการสื่อสาร กรมวิชาการเกษตร
# จาก : https://data.go.th

# %% [markdown]
# link Dive ที่รวมข้อมูล : https://drive.google.com/drive/folders/1eZqMV2DjOTmDAMDnwpyd-wEp5k75R47X

# %%
import pandas as pd #เพื่อใช้ทำงานกับข้อมูลที่เป็นรูปแบบตาราง
import os           #เพื่อจัดการกับไฟล์ และ ตัว path ที่เราจะนำเข้า

# %%
from google.colab import drive #เชื่อมข้อมูล เพราะเราจะทำการนำเข้าข้อมูล โดยให้ดึงมาจาก google drive ของเรา
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/DWDM_Project' #โดยเราจะทำการระบุให้ชี้ไปที่ โฟนเดอร์ที่เราเซฟไฟล์ไว้ หรือก็คือ โฟนเดอร์ DWDM_Project

# %% [markdown]
# ##คำอธิบายตาราง
#
# *  Title คือ ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ
#
# *  Subtitle_FC คือ ชื่อประเทศที่นำเข้าปุ๋ยเคมี
#
# *  Unit คือ คือ หน่วยในการนำเข้าปุ๋ยเคมี(เมตริกตัน)
#
# *  View คือ ข้อมูลเป็นของประเทศ
#
# *  Freq คือ ความถี่ในการนำเข้าป๋ยเคมีของแต่ละประเทศ คือเป็นรายปี
#
# *  Y2006-Y2018 คือ จำนวนการนำเข้าปุ๋ยเคมีของแต่ละปีของแต่ละประเทศ

# %%
data_fc = pd.read_csv(os.path.join(path,'importfertcountry.csv')) #การนำเข้าไฟล์ที่มีตัวแปรคือdata_fc
data_fc
# Out:
#     id                             Title  ...         Y2017       Y2018
# 0    1  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...  1,180,532.00         NaN
# 1    2  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...    949,696.61         NaN
# 2    3  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...    335,142.27         NaN
# 3    4  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...    654,577.16         NaN
# 4    5  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...    404,790.14         NaN
# 5    6  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...    578,495.49         NaN
# 6    7  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...    200,013.80   75,065.40
# 7    8  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...     30,216.83    4,292.37
# 8    9  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...    269,816.52  195,650.60
# 9   10  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...    326,780.02         NaN
# 10  11  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...     57,580.12   51,819.16
# 11  12  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...        162.03      128.07
# ...

# %%
data_fc.shape #.shape ใช้ข้อมูลว่า array นั้นมีสมาชิกกี่ตัว กี่แถว กี่คอลัมน์ กี่ตาราง ซึ่ง data_fc มี32แถว 19 คอลัมน์
# Out:
# (32, 19)

# %% [markdown]
# ##คำอธิบายตาราง
#
# *  Title คือ ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ
#
# *  Subtitle_FC คือ ชื่อประเทศที่นำเข้าปุ๋ยเคมี
#
# *  Unit คือ หน่วยในการนำเข้าปุ๋ยเคมี(เมตริกตัน)
#
# *  View คือ ข้อมูลเป็นของประเทศ
#
# *  Freq คือ ความถี่ในการนำเข้าปุ๋ยเคมีของแต่ละประเทศ คือเป็นรายปี
#
# *  Y2006-Y2018 คือ จำนวนการนำเข้าปุ๋ยเคมีของแต่ละปีของแต่ละประเทศ

# %%
data_fc.dropna() #ใช้ dropna เพื่อต้องการลบข้อมูลทั้งแถวออกเมื่อมีคอลัมน์ใดคอลัมน์หนึ่งเป็น NaN
# Out:
#     id                             Title  ...       Y2017       Y2018
# 6    7  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...  200,013.80   75,065.40
# 7    8  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...   30,216.83    4,292.37
# 8    9  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...  269,816.52  195,650.60
# 10  11  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...   57,580.12   51,819.16
# 11  12  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...      162.03      128.07
# 12  13  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...   46,376.21   79,850.77
# 14  15  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...   74,803.12   65,577.50
# 16  17  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...   60,971.94   63,381.83
# 17  18  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...    4,750.57    2,733.95
# 20  21  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...    2,105.40    1,017.40
# 21  22  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...  134,281.13   95,591.76
# 22  23  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...   19,711.00   13,091.50
# ...

# %% [markdown]
# ##คำอธิบายตาราง
#
# *  Title คือ ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุมรายประเทศ
#
# *  Subtitle_PC คือ ชื่อประเทศที่นำเข้าเมล็ดพันธุ์ควบคุม
#
# *  Unit คือ หน่วยของการนำเข้าเมล็ดพันธุ์ควบคุม(เมตริกตัน)
#
# *  View คือ ข้อมูลเป็นของประเทศ
#
# *  Freq คือ ความถี่ในการนำเข้าเมล็ดพันธุ์ควบคุมของแต่ละประเทศ คือเป็นรายปี
#
# *  Y2006-Y2020 คือ จำนวนการนำเข้าเมล็ดพันธุ์ควบคุมของแต่ละปีของแต่ละประเทศ

# %%
data_pc = pd.read_csv(os.path.join(path,'importplantcountry.csv'))  #การนำเข้าไฟล์ที่มีตัวแปรคือdata_pc
data_pc
# Out:
#     id                             Title  ...         Y2019         Y2020
# 0    1  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...      6,909.40      6,849.32
# 1    2  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...      3,023.29      3,460.13
# 2    3  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...           NaN           NaN
# 3    4  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...      5,947.01     18,978.08
# 4    5  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...           NaN           NaN
# 5    6  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...      9,152.59      8,830.02
# 6    7  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...    258,390.00  1,061,682.00
# 7    8  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...         153.7         312.5
# 8    9  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...    140,890.69    203,280.67
# 9   10  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...     37,915.23     42,485.37
# 10  11  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...    626,835.00    878,960.00
# 11  12  ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม  ...           NaN           NaN
# ...

# %% [markdown]
# ##คำอธิบายตาราง
#
# *  Title คือ ปริมาณการนำเข้าสารป้องกันและกำจัดโรคพืชรายประเทศ
#
# *  Subtitle_PD คือ ชื่อประเทศที่นำเข้าสารป้องกันและกำจัดโรคพืช
#
# *  Unit คือ หน่วยของการนำเข้าสารป้องกันและกำจัดโรคพืช(กิโลกรัม)
#
# *  View คือ ข้อมูลเป็นของประเทศ
#
# *  Freq คือ ความถี่ในการนำเข้าสารป้องกันและกำจัดโรคพืชของแต่ละประเทศ คือเป็นรายปี
#
# *  Y2006-Y2018 คือ จำนวนการนำเข้าสารป้องกันและกำจัดโรคพืชของแต่ละปีของแต่ละประเทศ

# %%
data_pd = pd.read_csv(os.path.join(path,'importpcidevol.csv')) #การนำเข้าไฟล์ที่มีตัวแปรคือdata_pd
data_pd
# Out:
#     id  ...             Y2020
# 0    1  ...      1,893,065.00
# 1    2  ...               NaN
# 2    3  ...      2,501,570.96
# 3    4  ...      2,592,601.20
# 4    5  ...        463,530.00
# 5    6  ...        372,827.00
# 6    7  ...               NaN
# 7    8  ...               NaN
# 8    9  ...        919,208.00
# 9   10  ...        397,400.00
# 10  11  ...        703,783.00
# 11  12  ...               NaN
# 12  13  ...               NaN
# 13  14  ...               NaN
# 14  15  ...        527,936.00
# 15  16  ...        422,001.00
# 16  17  ...    164,300,813.26
# 17  18  ...               NaN
# 18  19  ...    357,910,666.15
# 19  20  ...    647,514,387.97
# 20  21  ...     64,923,759.44
# 21  22  ...  1,303,291,817.82
# 22  23  ...               NaN
# 23  24  ...               NaN
# 24  25  ...     64,998,715.06
# 25  26  ...     71,455,250.21
# 26  27  ...    108,790,649.31
# 27  28  ...               NaN
# 28  29  ...               NaN
# 29  30  ...               NaN
# ...

# %% [markdown]
# ##คำอธิบายตาราง
# * Title_X คือ ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ
# * Title_Y คือ ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม
# * Subtitle_FC คือ ชื่อประเทศที่มีการนำเข้าปุ๋ยเคมีรายประเทศ
# * Subtitle_PC คือ ชื่อประเทศที่นำเข้าเมล็ดพันธุ์ควบคุม
# * Unit_X  คือ หน่วยในการนำเข้าปุ๋ยเคมี(เมตริกตัน)
# * Unit_Y  คือ หน่วยในการนำเข้าเมล็ดพันธุ์ควบคุม(เมตริกตัน)
# * View_X คือ ข้อมูลการนำเข้าปุ๋ยเคมี เป็นของประเทศ..
# * View_Y คือ ข้อมูลการนำเข้าเมล็ดพันธ์ุควบคุม เป็นของประเทศ..
# * Freq_X คือ ความถี่ในการนำเข้าปุ๋ยเคมีของแต่ละประเทศเป็นรายปี
# * Freq_Y คือ ความถี่ในการนำเข้าเมล็ดพันธ์ุควบคุมของแต่ละประเทศเป็นรายปี
# * Y2006_X-Y2018_X คือ จำนวนการนำเข้าปุ๋ยเคมี จากปี 2006-2018 ของแต่ละประเทศ
# * Y2006_Y-Y2020_Y คือ จำนวนการนำเข้าเมล็ดพันธุ์ควบคุม จากปี 2006-2018 ของแต่ละประเทศ

# %%
merged_data_fc_data_pc = data_fc.merge(data_pc,how='left',left_on='Subtitle_FC',right_on='Subtitle_PC')
merged_data_fc_data_pc #ใช้ merged เป็นการเชื่อมตาราง data_fc และ data_pc ในแนวแกนX
# Out:
#     id_x                           Title_x  ...         Y2019         Y2020
# 0      1  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...      6,909.40      6,849.32
# 1      2  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...      3,023.29      3,460.13
# 2      3  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...           NaN           NaN
# 3      4  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...      5,947.01     18,978.08
# 4      5  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...           NaN           NaN
# 5      6  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...      9,152.59      8,830.02
# 6      7  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...    258,390.00  1,061,682.00
# 7      8  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...         153.7         312.5
# 8      9  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...    140,890.69    203,280.67
# 9     10  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...     37,915.23     42,485.37
# 10    11  ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ  ...    626,835.00    878,960.00
# ...

# %% [markdown]
# ##คำอธิบายตาราง
#
# * Title คือ ปริมาณการนำเข้าสารป้องกันและกำจัดโรคพืช
# * Title_X คือ ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ
# * Title_Y คือ ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม
# * Subtitle_PD คือ ชื่อประเทศที่มีการนำเข้าสารป้องกันและกำจัดโรคพืช
# * Subtitle_FC คือ ชื่อประเทศที่มีการนำเข้าปุ๋ยเคมีรายประเทศ
# * Subtitle_PC คือ ชื่อประเทศที่นำเข้าเมล็ดพันธุ์ควบคุม
# * Unit คือ หน่วยในการนำเข้าสารป้องกันและกำจัดโรคพืช(กิโลกรัม)
# * Unit_X  คือ หน่วยในการนำเข้าปุ๋ยเคมี(เมตริกตัน)
# * Unit_Y  คือ หน่วยในการนำเข้าเมล็ดพันธุ์ควบคุม(เมตริกตัน)
# * View คือ ข้อมูลการนำเข้าสารป้องกันและกำจัดโรคพืชเป็นของประเทศ..
# * View_X คือ ข้อมูลการนำเข้าปุ๋ยเคมี เป็นของประเทศ..
# * View_Y คือ ข้อมูลการนำเข้าเมล็ดพันธ์ุควบคุม เป็นของประเทศ..
# * Freq คือ ความถี่ในการนำเข้าสารป้องกันและกำจัดโรคพืชของแต่ละประเทศเป็นรายปี
# * Freq_X คือ ความถี่ในการนำเข้าปุ๋ยเคมีของแต่ละประเทศเป็นรายปี
# * Freq_Y คือ ความถี่ในการนำเข้าเมล็ดพันธ์ุควบคุมของแต่ละประเทศเป็นรายปี
# * Y2007-Y2020 คือ จำนวนการนำเข้าสารป้องกันและกำจัดโรคพืช จากปี 2007-2020 ของแต่ละประเทศ
# * Y2006_X-Y2018_X คือ จำนวนการนำเข้าปุ๋ยเคมี จากปี 2006-2018 ของแต่ละประเทศ
# * Y2006_Y-Y2020_Y คือ จำนวนการนำเข้าเมล็ดพันธุ์ควบคุม จากปี 2006-2018 ของแต่ละประเทศ

# %%
merged_03 = data_pd.merge(merged_data_fc_data_pc,how='left',left_on='Subtitle_PD',right_on='Subtitle_PC') #ใช้merged_03 เพื่อเชื่อมตารางเข้าด้วยกัน
merged_03
# Out:
#     id  ...       Y2020_y
# 0    1  ...      6,849.32
# 1    2  ...      3,460.13
# 2    3  ...           NaN
# 3    4  ...     18,978.08
# 4    5  ...           NaN
# 5    6  ...      8,830.02
# 6    7  ...  1,061,682.00
# 7    8  ...         312.5
# 8    9  ...    203,280.67
# 9   10  ...     42,485.37
# 10  11  ...    878,960.00
# 11  12  ...           NaN
# 12  13  ...    287,500.00
# 13  14  ...         10.97
# 14  15  ...  1,994,106.49
# 15  16  ...           NaN
# 16  17  ...     16,646.96
# 17  18  ...    245,977.05
# 18  19  ...           115
# 19  20  ...    541,051.90
# 20  21  ...            14
# 21  22  ...           NaN
# 22  23  ...    862,245.60
# 23  24  ...  1,414,566.67
# 24  25  ...     12,622.18
# 25  26  ...      5,154.40
# 26  27  ...           NaN
# 27  28  ...      1,200.00
# 28  29  ...           NaN
# 29  30  ...           NaN
# 30  31  ...           NaN
# 31  32  ...           NaN
#
# [32 rows x 60 columns]

# %% [markdown]
# จากข้อมูลของตารางเบื้องต้น จะเห็นว่า มีข้อมูลที่เป็น NaN หรือ Not a Number เป็นจำนวนมาก ดังนั้นต้องทำการกำจัดค่า Missing value

# %%
merged_03.shape #.shape ใช้ข้อมูลว่า array นั้นมีสมาชิกกี่ตัว กี่แถว กี่คอลัมน์ กี่ตาราง ซึ่ง ตาราง merged_03 มี32 แถว 60 คอลัมน์
# Out:
# (32, 60)

# %%
merged_03.dropna().shape #ใช้ dropna เพื่อต้องการลบข้อมูลทั้งแถวออกเมื่อมีคอลัมน์ใดคอลัมน์หนึ่งเป็น NaN และใช้ .shape  เพื่อตรวจสอบว่ามี NAN กี่แถว กี่คอลัมน์
# Out:
# (4, 60)

# %%
merged_03.dropna().shape[0] #มีNAN 4 แถว
# Out:
# 4

# %% [markdown]
# คำนวณข้อมูลว่าหายไปกี่เปอร์เซ็น

# %%
removes = merged_03.shape[0] - merged_03.dropna().shape[0]
print(f'size before drop = {merged_03.shape[0]}')
print(f'size after drop = {merged_03.dropna().shape[0]}')
print(f'we lost {100*(removes/merged_03.shape[0])}% of data') #จากการคำนวณพบว่ามีข้อมูลที่หายไปถึง 87.5%
# Out:
# size before drop = 32
# size after drop = 4
# we lost 87.5% of data

# %% [markdown]
# จากการหาเปอร์เซ็นของข้อมูลที่โดนตัดไปจากการกำจัด Missing โดยการ dropna พบว่ามีข้อมูลหายไป 87.5% ซึ่งไม่สมควร ดังนั้นควรใช้วิธีการกำจัดแบบอื่น

# %% [markdown]
# จากการพิจารณา Handle Missing Value แล้วพบว่า ข้อมูลของเราเป็น Numeric ดังนั้นต้องแทนค่าด้วยค่ากลาง(mean)

# %%
merged_03.mean() #หาค่ามีนทั้งหมด
# Out:
# id      16.5
# id_x    16.5
# id_y    16.5
# dtype: float64

# %% [markdown]
# แต่ในที่นี้เราสนใจคอลัมน์ ปี 2015

# %%
merged_03[['Y2015']].mean()
#เติมมีนลงไปแทนค่า missing
#เราสามารถใช้ data.mean() ได้เพื่อหาค่ามีนทั้งหมดแต่จะนาน ดังนี้ชี้แค่ส่วนที่เราสนใจ
# Out:
# Series([], dtype: float64)

# %%
avg_age=merged_03[['Y2015']].mean()
merged_03[['Y2015']] = merged_03[['Y2015']].fillna('Y2015')#ใช้ fillna เพื่อแทนค่าของ missing

# %%
merged_03.isnull().any()
# Out:
# id             False
# Title          False
# Subtitle_PD    False
# Unit           False
# View           False
# Freq           False
# Y2007           True
# Y2008           True
# Y2009           True
# Y2010           True
# Y2011           True
# Y2012           True
# Y2013           True
# Y2014           True
# Y2015          False
# Y2016           True
# Y2017           True
# Y2018           True
# Y2019_x         True
# Y2020_x         True
# id_x           False
# Title_x        False
# Subtitle_FC    False
# Unit_x         False
# View_x         False
# Freq_x         False
# Y2006_x        False
# Y2007_x        False
# Y2008_x        False
# Y2009_x        False
# Y2010_x        False
# Y2011_x        False
# Y2012_x        False
# Y2013_x        False
# Y2014_x         True
# Y2015_x         True
# Y2016_x         True
# Y2017_x         True
# Y2018_x         True
# id_y           False
# Title_y        False
# Subtitle_PC    False
# Unit_y         False
# ...

# %% [markdown]
# หาข้อมูลเพิ่ม

# %%
path = '/content/drive/My Drive/DWDM_Project' #โดยเราจะทำการระบุให้ชี้ไปที่ โฟนเดอร์ที่เราเซฟไฟล์ไว้ หรือก็คือ โฟนเดอร์ DWDM_Project

# %% [markdown]
# ##คำอธิบายตาราง
#
# * country คือ ชื่อประเทศที่นำเข้าสินค้าทางการเกษตร
#
# * View คือ ข้อมูลเป็นของประเทศ
#
# * population(million)	คือ จำนวนการนำเข้าสินค้าทางการเกษตร(ล้าน)
#
# * religion คือ ศาสนาที่นับถือ
#
# * capital คือ เมืองหลวง
#
# * language คือ ภาษาที่ใช้

# %%
data_add = pd.read_csv(os.path.join(path,'ข้อมูลทั่วไปของประเทศที่นำเข้าสินค้าทางการเกษตร.xlsx - Sheet1.csv')) #
data_add
# Out:
#     id                   country  ...          capital                      language
# 0    1              SAUDI ARABIA  ...            ริยาด                        อาหรับ
# 1    2                     CHINA  ...          ปักกิ่ง                       จีนกลาง
# 2    3        KOREA  REPUBLIC OF  ...              โซล                        เกาหลี
# 3    4                     QATAR  ...             โดฮา                        อาหรับ
# 4    5                  MALAYSIA  ...    กัวลาลัมเปอร์                         มลายู
# 5    6  RUSSIAN FEDERATION (CIS)  ...     มินสค์/มอสโก                       รัสเซีย
# 6    7                    KUWAIT  ...        คูเวตซิตี                        อาหรับ
# 7    8                     EGYPT  ...             ไคโร                        อาหรับ
# 8    9                    NORWAY  ...            ออสโล                      นอร์เวย์
# 9   10                    CANADA  ...          ออตตาวา               อังกฤษ/ฝรั่งเคส
# ...

# %% [markdown]
# ##คำอธิบายตาราง
#
# * country คือ ชื่อประเทศที่นำเข้าสินค้าทางการเกษตร
# * View คือ ข้อมูลการนำเข้าสารป้องกันและกำจัดโรคพืชเป็นของประเทศ..
# * View_X คือ ข้อมูลการนำเข้าปุ๋ยเคมี เป็นของประเทศ..
# * View_Y คือ ข้อมูลการนำเข้าเมล็ดพันธ์ุควบคุม เป็นของประเทศ..
# * population(million)	คือ จำนวนการนำเข้าสินค้าทางการเกษตร(ล้าน)
# * religion คือ ศาสนาที่นับถือ
# * capital คือ เมืองหลวง
# * language คือ ภาษาที่ใช้
# * Title คือ ปริมาณการนำเข้าสารป้องกันและกำจัดโรคพืช
# * Title_X คือ ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ
# * Title_Y คือ ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม
# * Subtitle_PD คือ ชื่อประเทศที่มีการนำเข้าสารป้องกันและกำจัดโรคพืช
# * Subtitle_FC คือ ชื่อประเทศที่มีการนำเข้าปุ๋ยเคมีรายประเทศ
# * Subtitle_PC คือ ชื่อประเทศที่นำเข้าเมล็ดพันธุ์ควบคุม
# * Unit คือ หน่วยในการนำเข้าสารป้องกันและกำจัดโรคพืช(กิโลกรัม)
# * Unit_X  คือ หน่วยในการนำเข้าปุ๋ยเคมี(เมตริกตัน)
# * Unit_Y  คือ หน่วยในการนำเข้าเมล็ดพันธุ์ควบคุม(เมตริกตัน)
# * Freq คือ ความถี่ในการนำเข้าสารป้องกันและกำจัดโรคพืชของแต่ละประเทศเป็นรายปี
# * Freq_X คือ ความถี่ในการนำเข้าปุ๋ยเคมีของแต่ละประเทศเป็นรายปี
# * Freq_Y คือ ความถี่ในการนำเข้าเมล็ดพันธ์ุควบคุมของแต่ละประเทศเป็นรายปี
# * Y2007-Y2020 คือ จำนวนการนำเข้าสารป้องกันและกำจัดโรคพืช จากปี 2007-2020 ของแต่ละประเทศ
# * Y2006_X-Y2018_X คือ จำนวนการนำเข้าปุ๋ยเคมี จากปี 2006-2018 ของแต่ละประเทศ
# * Y2006_Y-Y2020_Y คือ จำนวนการนำเข้าเมล็ดพันธุ์ควบคุม จากปี 2006-2018 ของแต่ละประเทศ
#
# ---

# %%
merged_04 = data_add.merge(merged_03,how='left',left_on='country',right_on='Subtitle_PD')
merged_04
# Out:
#     id_x                   country  ...       Y2019_y       Y2020_y
# 0      1              SAUDI ARABIA  ...      6,909.40      6,849.32
# 1      2                     CHINA  ...      3,023.29      3,460.13
# 2      3        KOREA  REPUBLIC OF  ...           NaN           NaN
# 3      4                     QATAR  ...      5,947.01     18,978.08
# 4      5                  MALAYSIA  ...           NaN           NaN
# 5      6  RUSSIAN FEDERATION (CIS)  ...      9,152.59      8,830.02
# 6      7                    KUWAIT  ...    258,390.00  1,061,682.00
# 7      8                     EGYPT  ...         153.7         312.5
# 8      9                    NORWAY  ...    140,890.69    203,280.67
# 9     10                    CANADA  ...     37,915.23     42,485.37
# 10    11                    ISRAEL  ...    626,835.00    878,960.00
# 11    12                     JAPAN  ...           NaN           NaN
# 12    13                   BAHRAIN  ...           NaN    287,500.00
# ...

# %% [markdown]
# ##คำอธิบายตาราง
# * Title คือ ปริมาณการนำเข้าสารป้องกันและกำจัดโรคพืช
# * Title_X คือ ปริมาณการนำเข้าปุ๋ยเคมีรายประเทศ
# * Title_Y คือ ปริมาณการนำเข้าเมล็ดพันธุ์ควบคุม
# * Subtitle_PD คือ ชื่อประเทศที่มีการนำเข้าสารป้องกันและกำจัดโรคพืช
# * Subtitle_FC คือ ชื่อประเทศที่มีการนำเข้าปุ๋ยเคมีรายประเทศ
# * Subtitle_PC คือ ชื่อประเทศที่นำเข้าเมล็ดพันธุ์ควบคุม
# * Unit คือ หน่วยในการนำเข้าสารป้องกันและกำจัดโรคพืช(กิโลกรัม)
# * Unit_X  คือ หน่วยในการนำเข้าปุ๋ยเคมี(เมตริกตัน)
# * Unit_Y  คือ หน่วยในการนำเข้าเมล็ดพันธุ์ควบคุม(เมตริกตัน)
# * View คือ ข้อมูลการนำเข้าสารป้องกันและกำจัดโรคพืชเป็นของประเทศ..
# * View_X คือ ข้อมูลการนำเข้าปุ๋ยเคมี เป็นของประเทศ..
# * View_Y คือ ข้อมูลการนำเข้าเมล็ดพันธ์ุควบคุม เป็นของประเทศ..
# * Freq คือ ความถี่ในการนำเข้าสารป้องกันและกำจัดโรคพืชของแต่ละประเทศเป็นรายปี
# * Freq_X คือ ความถี่ในการนำเข้าปุ๋ยเคมีของแต่ละประเทศเป็นรายปี
# * Freq_Y คือ ความถี่ในการนำเข้าเมล็ดพันธ์ุควบคุมของแต่ละประเทศเป็นรายปี
# * Y2007-Y2020 คือ จำนวนการนำเข้าสารป้องกันและกำจัดโรคพืช จากปี 2007-2020 ของแต่ละประเทศ
# * Y2006_X-Y2018_X คือ จำนวนการนำเข้าปุ๋ยเคมี จากปี 2006-2018 ของแต่ละประเทศ
# * Y2006_Y-Y2020_Y คือ จำนวนการนำเข้าเมล็ดพันธุ์ควบคุม จากปี 2006-2018 ของแต่ละประเทศ

# %%
merged_03
# Out:
#     id  ...       Y2020_y
# 0    1  ...      6,849.32
# 1    2  ...      3,460.13
# 2    3  ...           NaN
# 3    4  ...     18,978.08
# 4    5  ...           NaN
# 5    6  ...      8,830.02
# 6    7  ...  1,061,682.00
# 7    8  ...         312.5
# 8    9  ...    203,280.67
# 9   10  ...     42,485.37
# 10  11  ...    878,960.00
# 11  12  ...           NaN
# 12  13  ...    287,500.00
# 13  14  ...         10.97
# 14  15  ...  1,994,106.49
# 15  16  ...           NaN
# 16  17  ...     16,646.96
# 17  18  ...    245,977.05
# 18  19  ...           115
# 19  20  ...    541,051.90
# 20  21  ...            14
# 21  22  ...           NaN
# 22  23  ...    862,245.60
# 23  24  ...  1,414,566.67
# 24  25  ...     12,622.18
# 25  26  ...      5,154.40
# 26  27  ...           NaN
# 27  28  ...      1,200.00
# 28  29  ...           NaN
# 29  30  ...           NaN
# 30  31  ...           NaN
# 31  32  ...           NaN
#
# [32 rows x 60 columns]

# %% [markdown]
# ##เสร็จ
