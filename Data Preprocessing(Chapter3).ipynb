# %% [markdown]
# <a href="https://colab.research.google.com/github/khanittha-phusopha/DWDM21/blob/main/Data%20Preprocessing(Chapter3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #เพราะเราจะจัดการข้อมูลกราฟ

# %%
from google.colab import drive #ใช้เชื่อมกูเกิ้ลไดร์ฟ กดลิ๊งค์ เลือกบัญชี คัดลอก แล้วมาสี่ที่ช่องสี่เหลี่ยม แล้วกดเอนเทอร์
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
path = '/content/drive/My Drive/DWDM2021_DATA'

# %%
data = pd.read_csv(os.path.join(path,'confirmed-cases (1).csv'))
data
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 597226  597227     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597227  597228     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597228  597229     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597229  597230     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597230  597231     31/7/2021  ...     กรุงเทพมหานคร               NaN
#
# [597231 rows x 11 columns]

# %% [markdown]
# ในบทที่ 3 เราจะดูข้อมูลให้ละเอียดมากกว่าบทที่สอง

# %% [markdown]
# ##Meta Data คือ ดาต้าที่ใช้อธิบายดาต้า
# หรือก็คือ Data Dict.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##ชี้ข้อมูลในตาราง

# %% [markdown]
# ### ชี้แบบธรรมดา ใช้ [ชื่อ column][index]

# %%
data['risk'][678] #ทุกครั้งที่ชี้ให้เลือกคอลัมน์ แล้วตามด้วน index
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %%
data[['age','risk','sex']] #ดึงเฉพาะคอลัมน์ที่เราต้องการ
# Out:
#          age                              risk   sex
# 0       61.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# 1       74.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# 2       73.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# 3       68.0  คนต่างชาติเดินทางมาจากต่างประเทศ   ชาย
# 4       66.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# ...      ...                               ...   ...
# 597226  24.0                  ทัณฑสถาน/เรือนจำ  หญิง
# 597227  35.0                  ทัณฑสถาน/เรือนจำ  หญิง
# 597228  41.0                  ทัณฑสถาน/เรือนจำ  หญิง
# 597229  34.0                  ทัณฑสถาน/เรือนจำ  หญิง
# 597230  41.0                  ทัณฑสถาน/เรือนจำ   ชาย
#
# [597231 rows x 3 columns]

# %% [markdown]
# ### ชี้แบบ .iloc[] (มองข้อมูลเป็น metrix)
#
# [แถว,หลัก]

# %%
data.iloc[678,8]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %%
data.iloc[-10:,4:9:2]
# Out:
#          age nationality              risk
# 597221  40.0         NaN  ทัณฑสถาน/เรือนจำ
# 597222  24.0         NaN  ทัณฑสถาน/เรือนจำ
# 597223  35.0         NaN  ทัณฑสถาน/เรือนจำ
# 597224  29.0         NaN  ทัณฑสถาน/เรือนจำ
# 597225  33.0         NaN  ทัณฑสถาน/เรือนจำ
# 597226  24.0         NaN  ทัณฑสถาน/เรือนจำ
# 597227  35.0         NaN  ทัณฑสถาน/เรือนจำ
# 597228  41.0         NaN  ทัณฑสถาน/เรือนจำ
# 597229  34.0         NaN  ทัณฑสถาน/เรือนจำ
# 597230  41.0         NaN  ทัณฑสถาน/เรือนจำ

# %%
data.iloc[-10:,[3,4,8]]
# Out:
#          sex   age              risk
# 597221  หญิง  40.0  ทัณฑสถาน/เรือนจำ
# 597222  หญิง  24.0  ทัณฑสถาน/เรือนจำ
# 597223  หญิง  35.0  ทัณฑสถาน/เรือนจำ
# 597224  หญิง  29.0  ทัณฑสถาน/เรือนจำ
# 597225  หญิง  33.0  ทัณฑสถาน/เรือนจำ
# 597226  หญิง  24.0  ทัณฑสถาน/เรือนจำ
# 597227  หญิง  35.0  ทัณฑสถาน/เรือนจำ
# 597228  หญิง  41.0  ทัณฑสถาน/เรือนจำ
# 597229  หญิง  34.0  ทัณฑสถาน/เรือนจำ
# 597230   ชาย  41.0  ทัณฑสถาน/เรือนจำ

# %% [markdown]
# ##Missing Value
#
# *NaN = Not a Number
#
# *Null ช่องว่าง
#
# *NA = Not Available

# %%
data.describe()
# Out:
#                  No.            age
# count  597231.000000  539864.000000
# mean   298616.000000      35.544612
# std    172405.883646      16.275674
# min         1.000000       1.000000
# 25%    149308.500000      25.000000
# 50%    298616.000000      34.000000
# 75%    447923.500000      46.000000
# max    597231.000000     114.000000

# %% [markdown]
# จากการ เรียกดูคำอธิบายข้อมูลจะเห็นว่า count No. and age มีค่าไม่ตรงกัน อาจเกิดจากการไม่ได้กรอกข้อมูล

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(data['age']) #ยังพล็อตไม่ได้ เพราะข้อมูลยังมี missing
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f744b18a650>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f744b197690>,
#   <matplotlib.lines.Line2D at 0x7f744b197bd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f744b11f6d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f744b11f190>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f744b18abd0>,
#   <matplotlib.lines.Line2D at 0x7f744b197150>]}

# %%
data.isnull() #ดูว่าข้อมูลส่วนไหนที่เป็นช่องว่างบ้าง แต่จะไม่ค่อยช่วย
# Out:
#           No.  announce_date  ...  province_of_onset  district_of_onset
# 0       False          False  ...              False               True
# 1       False          False  ...              False               True
# 2       False          False  ...              False              False
# 3       False          False  ...              False               True
# 4       False          False  ...              False               True
# ...       ...            ...  ...                ...                ...
# 597226  False          False  ...              False               True
# 597227  False          False  ...              False               True
# 597228  False          False  ...              False               True
# 597229  False          False  ...              False               True
# 597230  False          False  ...              False               True
#
# [597231 rows x 11 columns]

# %%
data.isnull().any() #ดูให้ละเอียดมากขึ้นต้องเพิ่ม .any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ##วิธีกำจัด Missing
#
# Handle Missing Value 1 (ลบค่า Missing) เป็นวิธีง่านสุด

# %%
plt.boxplot(data['age'].dropna())
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f744ac5d9d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f744ac60a10>,
#   <matplotlib.lines.Line2D at 0x7f744ac60f50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f744ac67a50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f744ac67510>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f744ac5df50>,
#   <matplotlib.lines.Line2D at 0x7f744ac604d0>]}

# %%
data.dropna()
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 47          48      6/3/2020  ...     กรุงเทพมหานคร           คลองตัน
# 124        125      6/3/2021  ...          ปทุมธานี           ธัญบุรี
# 161        162     17/3/2020  ...      สุราษฎร์ธานี             เมือง
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 186        187     18/3/2020  ...          ร้อยเอ็ด         เชียงขวัญ
# ...        ...           ...  ...               ...               ...
# 595919  595920     31/7/2021  ...     กรุงเทพมหานคร       บางขุนเทียน
# 595920  595921     31/7/2021  ...     กรุงเทพมหานคร         ลาดกระบัง
# 595921  595922     31/7/2021  ...     กรุงเทพมหานคร           ยานนาวา
# 595922  595923     31/7/2021  ...     กรุงเทพมหานคร           ยานนาวา
# 596420  596421     31/7/2021  ...     กรุงเทพมหานคร              สาทร
#
# [424444 rows x 11 columns]

# %% [markdown]
# #Quiz3 หาว่าการทำ dropna() ทำให้ข้อมูลหายไปกี่ %

# %%
print('size before is =')
data.shape[0]
# Out:
# size before is =
# 597231

# %%
print('size before is =')
data.shape[0]
# Out:
# size before is =
# 597231

# %%
percen = data.shape[0] - data.dropna().shape[0]

# %%
so = 100*(percen/data.shape[0])

# %%
print('=')
so
# Out:
# =
# 28.931351520600906

# %% [markdown]
# เฉลยของอาจารย์

# %%
removes = data.shape[0] - data.dropna().shape[0]
print(f'size before drop = {data.shape[0]}')
print(f'size after drop = {data.dropna().shape[0]}')
print(f'we lost {100*(removes/data.shape[0])}% of data')
# Out:
# size before drop = 597231
# size after drop = 424444
# we lost 28.931351520600906% of data

# %% [markdown]
# ##Handle Missing Value 1.5 (ลบค่า Missing เฉพาะใน column ที่เราสนใจ)

# %%
data_nomissingAge = data.dropna(subset=['age'])

# %%
plt.boxplot(data_nomissingAge['age'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f744a15f190>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f744a163210>,
#   <matplotlib.lines.Line2D at 0x7f744a163750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f744a16a250>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f744a163cd0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f744a15f890>,
#   <matplotlib.lines.Line2D at 0x7f744a15f850>]}

# %% [markdown]
# ##Quiz 3.1 ให้ หาว่า การทำ .dropna() แบบเลือก drop ทำให้ข้อมูลหายกี่ %

# %%
remove = data.shape[0] - data_nomissingAge.shape[0]
print(f'size before drop = {data.shape[0]}')
print(f'size after drop = {data_nomissingAge.shape[0]}')
print(f'we lost {100*(remove/data.shape[0])}% of data')
# Out:
# size before drop = 597231
# size after drop = 539864
# we lost 9.605496030849036% of data

# %% [markdown]
# ##Handle Missing Value 2

# %%
data
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 597226  597227     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597227  597228     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597228  597229     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597229  597230     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597230  597231     31/7/2021  ...     กรุงเทพมหานคร               NaN
#
# [597231 rows x 11 columns]

# %%
data[['risk']] = data[['risk']].fillna('ไม่มีข้อมูล')

# %%
set(data['risk'])
# Out:
# {' Samui plus',
#  '2.สัมผัสผู้ติดเชื้อ',
#  'ACF รองเมือง',
#  'ACF สนามกีฬาธูปะเตมีย์',
#  'ACF สนามกีฬาไทย-ญี่ปุ่น',
#  'ACF สีลม',
#  'ACF เคหะหลักสี่',
#  'Cluster Icon siam',
#  "Cluster Memory 90's กรุงเทพมหานคร",
#  'Cluster New Jazz กรุงเทพมหานคร',
#  'Cluster The Lounge Salaya',
#  'Cluster กรุงเทพมหานคร. คลองเตย',
#  'Cluster คลองเตย',
#  'Cluster งานมอเตอร์ โชว์',
#  'Cluster จนท. สนามบินสุวรรณภูมิ',
#  'Cluster จันทบุรี',
#  'Cluster จันทบุรี (ชาวกินี )',
#  'Cluster จันทบุรี (ชาวกินี)',
#  'Cluster ชลบุรี',
#  'Cluster ชลบุรี บริษัทไดกิ้น',
#  'Cluster ชลบุรี โรงเบียร์ 90',
#  'Cluster ตราด',
#  'Cluster ตราด ',
#  'Cluster ตลาดนนทบุรี',
#  'Cluster ตลาดบางพลี',
#  'Cluster ตลาดบางแค',
#  'Cluster ตลาดบางแค/คลองขวาง',
#  'Cluster ตลาดพรพัฒน์',
#  'Cluster ตลาดสี่มุมเมือง',
#  'Cluster ทัณฑสถานหญิงกลาง',
#  'Cluster ทัณฑสถานโรงพยาบาลราชทัณฑ์',
#  'Cluster ทันฑสถานบำบัดพิเศษกลาง',
#  'Cluster บริษัทศรีสวัสดิ์',
#  'Cluster บางแค',
#  'Cluster บ่อนพัทยา/ชลบุรี',
#  'Cluster บ่อนเทพารักษ์',
#  'Cluster บ่อนไก่อ่างทอง',
#  'Cluster ปากช่อง',
#  'Cluster ผับ Thonglor',
#  'Cluster มหาสารคาม',
#  'Cluster ระยอง',
#  'Cluster ระยอง วิริยะประกันภัย',
#  'Cluster สถานบันเทิงย่านทองหล่อ',
#  'Cluster สมุทรปราการ (โรงงาน บริษัทเมทัล โปรดักส์)',
#  'Cluster สมุทรปราการ GRP Hightech',
#  'Cluster สมุทรปราการ ตลาดเคหะบางพลี',
#  'Cluster สมุทรสาคร',
#  'Cluster ห้างแสงทอง (สายล่าง)',
#  'Cluster เครือคัสเซ่อร์พีคโฮลดิ้ง (CPG,CPH)',
#  'Cluster เรือนจำกลางคลองเปรม',
#  'Cluster เรือนจำพิเศษกรุงเทพ',
#  'Cluster เรือนจำพิเศษธนบุรี',
#  'Cluster เรือนจำพิเศษมีนบุรี',
#  'Cluster โรงงาน  Big Star',
#  'Cluster โรงงาน Big Star',
#  'Cluster โรงงาน QPP ประจวบฯ',
#  'Cluster โรงงาน standard can',
#  'Cluster โรงงานทำขนม บางขุนเทียน',
#  'Refer in',
#  'SHUI',
#  'Sandbox',
#  'State Quarantine',
#  'cluster ชลบุรี\n(อยู่ระหว่างการสอบสวน)',
#  'การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน',
#  'คนต่างชาติเดินทางมาจากต่างประเทศ',
#  'คนไทยมาจากพื้นที่เสี่ยง',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คนไทยเดินทางมาจากต่างประเทศ',
#  'ค้นหาเชิงรุก',
#  'ตรวจก่อนทำหัตถการ',
#  'ตรวจสุขภาพแรงงานต่างด้าว',
#  'ตลาด',
#  'ทัณฑสถาน/เรือนจำ',
#  'บุคลากรด้านการแพทย์และสาธารณสุข',
#  'ปอดอักเสบ (Pneumonia)',
#  'ปอดอักเสบ Pneumonia',
#  'ผับหัวหิน',
#  'ผู้ติดเชื้อในประเทศ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AOQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า HQ/AHQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า OQ',
#  'ผู้ป่วย PUI',
#  'ผู้ป่วย กรุงเทพมหานคร',
#  'ผู้เดินทางมาจากพื้นที่เสี่ยง กรุงเทพมหานคร.',
#  'พิธีกรรมทางศาสนา',
#  'มาจากพื้นที่เสียง จ.ปทุมธานี',
#  'มาจากพื้นที่เสี่ยง',
#  'มาจากพื้นที่เสี่ยง จ.ปทุมธานี',
#  'รอประสาน',
#  'ระบุไม่ได้',
#  'ระหว่างการสอบสวนโรค',
#  'ระหว่างสอบสวน',
#  'รับจ้างขนของที่ตลาดท่ายาง',
#  'ร้านอาหาร',
#  'ศูนย์กักกัน ผู้ต้องกัก',
#  'สถานที่ทำงาน',
#  'สถานบันเทิง',
#  'สน.วัดพระยาไกร',
#  'สนามมวย',
#  'สัมผัสผู้ติดเชื้อยืนยัน\nอยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ติดเชื้อยืนยัน อยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยที่ติดโควิด',
#  'สัมผัสผู้ป่วยยืนยัน',
#  'สัมผัสผู้ป่วยยืนยัน \n อยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยยืนยัน (ยังไม่สามารถระบุได้)',
#  'สัมผัสผู้ป่วยยืนยัน ภายในครอบครัว/ชุมชน/เพื่อน',
#  'สัมผัสผู้ป่วยยืนยัน อยุ๋ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยยืนยัน อยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยยืนยันเพื่อนร่วมงาน',
#  'สัมผัสผู้เดินทางจากต่างประเทศ',
#  'สัมผัสสามีสะอาด เขตบ้าน (รพ.มหาชัย 2)',
#  'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้',
#  'สัมผัสใกล้ชิดผู้ป่วยยันยันก่อนหน้า',
#  'สัมผัสใกล้ชิดผู้ป่วยยืนยันก่อนหน้า',
#  'สัมผัสในสถานพยาบาล',
#  'อยุ่ระหว่างสอบสวน',
#  'อยู่ระหว่างการสอบสวน',
#  'อยู่ระหว่างการสอบสวน\n',
#  'อยู่ระหว่างสอบสวน',
#  'อยู่ระหว่างสอบสวนโรค',
#  'อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น',
#  'อาศัย/เดินทางไปในพื้นที่ที่มีการระบาด',
#  'อื่น',
#  'อื่นๆ',
#  'เดินทางมาจากพื้นที่จังหวัดเสี่ยง',
#  'เดินทางมาจากพื้นที่มีการระบาดของโรค',
#  'เดินทางมาจากพื้นที่เสี่ยง จ.กรุงเทพฯ จอมทอง',
#  'เดินทางมาจากพื้นที่เสี่ยงที่มีการระบาดของโรค',
#  'แรงงานต่างด้าวตรวจก่อนขึ้นทะเบียน',
#  'ไปยัง/มาจาก พื้นที่ระบาดกรุงเทพมหานครมหานคร',
#  'ไปยังพื้นที่ที่มีการระบาด',
#  'ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว',
#  'ไปสถานที่เสี่ยง เช่น ตลาด สถานที่ชุมชน',
#  'ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต',
#  'ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar',
#  'ไปแหล่งชุมชน/สถานที่คนหนาแน่น',
#  'ไม่มีข้อมูล'}

# %% [markdown]
# ##Handle Missing Value 3 (แทนด้วย class ใหม่ (ค่าที่เหมาะสม))

# %%
set(data['Unit']) #จะเห็นว่ามีข้อมูลซ้ำกันคือ วัน กับ ปี
# Out:
# {' วัน', ' เดือน', nan, 'ปี', 'วัน', 'เดือน'}

# %%
# เติมค่าว่างในช่องที่ไม่มีข้อมูล
data[['Unit']] = data[['Unit']].fillna('ปี?')

# %%
data.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                     False
# nationality               True
# province_of_isolation     True
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ##Handling Missing Value 4 (แทนด้วยค่ากลาง)

# %% [markdown]
# ถ้าเป็น numeric ใช้ mean

# %%
data[['age']].mean() #เติมมีนลงไปแทนค่า missing
#เราสามารถใช้ data.mean() ได้เพื่อหาค่ามีนทั้งหมดแต่จะนาน ดังนี้ชี้แค่ส่วนที่เราสนใจ
# Out:
# age    35.544612
# dtype: float64

# %%
avg_age=data[['age']].mean()
data[['age']] = data[['age']].fillna('avg_age') #ใช้ fillna เพื่อแทนค่าของ missing

# %%
data.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                      False
# Unit                     False
# nationality               True
# province_of_isolation     True
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data[['age']].mean() #ตรวจสอบดูค่ากลางอีกครั้ง
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ถ้าเป็น norminal หรือ ตัวหนังสือ จะใช้ mode

# %%
data[['nationality']].mean()
# Out:
# Series([], dtype: float64)

# %%
data[['nationality']].mode()
# Out:
#   nationality
# 0    Thailand

# %%
data[['nationality']].mode().iloc[0,0]
# Out:
# 'Thailand'

# %%
data['nationality'].mode()
# Out:
# 0    Thailand
# dtype: object

# %%
# หา mode
mode_nation = data[['nationality']].mode()
# เติม mean ลงไปแทนค่า missing
data[['nationality']] = data[['nationality']].fillna(mode_nation.iloc[0,0])

# %%
data.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ถ้าเป็น ordinal ใช้ medain

# %%
data.head(20)
# Out:
#     No. announce_date  ... province_of_onset district_of_onset
# 0     1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1     2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2     3     22/1/2020  ...            นครปฐม             เมือง
# 3     4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4     5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# 5     6     25/1/2020  ...     กรุงเทพมหานคร               NaN
# 6     7     26/1/2020  ...     กรุงเทพมหานคร               NaN
# 7     8     26/1/2020  ...   ประจวบคีรีขันธ์            หัวหิน
# 8     9     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 9    10     28/1/2020  ...           นนทบุรี               NaN
# 10   11     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 11   12     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 12   13     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 13   14     28/1/2020  ...            ภูเก็ต             เมือง
# 14   15     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 15   16     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 16   17     31/1/2020  ...         เชียงใหม่             หางดง
# 17   18     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 18   19     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 19   20      4/2/2020  ...     กรุงเทพมหานคร               NaN
#
# [20 rows x 11 columns]

# %% [markdown]
# ##Handling Missing Value 5 (แทนด้วย column ใกล้เคียง)

# %%
data_cases2 = pd.read_csv(os.path.join(path,'confirmed-cases (1).csv'))
data_cases2
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 597226  597227     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597227  597228     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597228  597229     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597229  597230     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597230  597231     31/7/2021  ...     กรุงเทพมหานคร               NaN
#
# [597231 rows x 11 columns]

# %% [markdown]
# ##Select data by values [PD]
#
# การเลือก record สามารถเลือกโดยใช้ list ของ boolean(ความยาวของ list เท่ากับ จำนวน record)
#
# ชื่อตาราง[list ของ boolean]
#
# **สร้าง list ของ boolean**

# %%
data_cases2['risk'] == 'ทัณฑสถาน/เรือนจำ'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 597226     True
# 597227     True
# 597228     True
# 597229     True
# 597230     True
# Name: risk, Length: 597231, dtype: bool

# %% [markdown]
# นำ list ของ boolean มาเลือกค่าในตาราง

# %%
data_cases2[data_cases2['risk'] == 'ทัณฑสถาน/เรือนจำ']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 100018  100019     16/5/2021  ...        ฉะเชิงเทรา  เมืองฉะเชิงเทรา‎
# 100019  100020     16/5/2021  ...        ฉะเชิงเทรา  เมืองฉะเชิงเทรา‎
# 101468  101469     17/5/2021  ...               NaN               NaN
# 101469  101470     17/5/2021  ...               NaN               NaN
# 101470  101471     17/5/2021  ...               NaN               NaN
# ...        ...           ...  ...               ...               ...
# 597226  597227     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597227  597228     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597228  597229     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597229  597230     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597230  597231     31/7/2021  ...     กรุงเทพมหานคร               NaN
#
# [43530 rows x 11 columns]

# %% [markdown]
# สร้าง list ของ boolean

# %%
data_cases2['age'] > 70
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 597226    False
# 597227    False
# 597228    False
# 597229    False
# 597230    False
# Name: age, Length: 597231, dtype: bool

# %%
data_cases2[data_cases2['age'] > 70]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 7            8     26/1/2020  ...   ประจวบคีรีขันธ์            หัวหิน
# 82          83     15/3/2020  ...     กรุงเทพมหานคร               NaN
# 119        120     16/3/2020  ...        ฉะเชิงเทรา               NaN
# ...        ...           ...  ...               ...               ...
# 595745  595746     31/7/2021  ...     กรุงเทพมหานคร          ดอนเมือง
# 595756  595757     31/7/2021  ...     กรุงเทพมหานคร            พระนคร
# 595760  595761     31/7/2021  ...     กรุงเทพมหานคร           หนองจอก
# 595880  595881     31/7/2021  ...     กรุงเทพมหานคร            ประเวศ
# 597212  597213     31/7/2021  ...     กรุงเทพมหานคร               NaN
#
# [13804 rows x 11 columns]

# %%
blist_age70up = data_cases2['age'] > 70

# %%
blist_female = data_cases2['sex'] == 'หญิง'
blist_female
# Out:
# 0          True
# 1          True
# 2          True
# 3         False
# 4          True
#           ...
# 597226     True
# 597227     True
# 597228     True
# 597229     True
# 597230    False
# Name: sex, Length: 597231, dtype: bool

# %% [markdown]
# ##เราใช้ & (and) และ | (or) ในการรวม list ของ boolean

# %%
blist_age70up & blist_female
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 597226    False
# 597227    False
# 597228    False
# 597229    False
# 597230    False
# Length: 597231, dtype: bool

# %%
data_cases2[blist_age70up & blist_female]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 7            8     26/1/2020  ...   ประจวบคีรีขันธ์            หัวหิน
# 476        477     22/3/2020  ...     กรุงเทพมหานคร         ภาษีเจริญ
# 564        565     22/3/2020  ...           นนทบุรี               NaN
# ...        ...           ...  ...               ...               ...
# 595654  595655     31/7/2021  ...     กรุงเทพมหานคร           หนองจอก
# 595715  595716     31/7/2021  ...     กรุงเทพมหานคร            ธนบุรี
# 595737  595738     31/7/2021  ...     กรุงเทพมหานคร           คลองสาน
# 595756  595757     31/7/2021  ...     กรุงเทพมหานคร            พระนคร
# 595880  595881     31/7/2021  ...     กรุงเทพมหานคร            ประเวศ
#
# [7459 rows x 11 columns]

# %% [markdown]
# ### Quiz 4 and HW
#
# เลือก rocords ต่อไปนี้
#
# 1.rocords ที่ กักตัวในขอนแก่น
#
# 2.rocords ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร
#
# 3.rocords ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม.
#
# 4.rocords ที่ เป็นผู้ชาย อายุ 18-22ปี ที่กักตัวที่เชียงใหม่
#
# 5.หาอายุเฉลี่ยของคนที่พบเชื้อที่ขอนแก่น

# %%
data
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 597226  597227     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597227  597228     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597228  597229     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597229  597230     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597230  597231     31/7/2021  ...     กรุงเทพมหานคร               NaN
#
# [597231 rows x 11 columns]

# %%
import statistics as stats

# %%
data_cases2['province_of_isolation'] == 'ขอนแก่น' #ข้อหนึ่ง ชี้ไปที่ province_of_isolation
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 597226    False
# 597227    False
# 597228    False
# 597229    False
# 597230    False
# Name: province_of_isolation, Length: 597231, dtype: bool

# %% [markdown]
# จะเห็นว่า ข้อมูล False ดังนั้นเรียกดูตาราง เพื่อดูค่าข้อมูล

# %%
data_cases2[data_cases2['province_of_isolation'] == 'ขอนแก่น']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 588504  588505     31/7/2021  ...     กรุงเทพมหานคร            บางจาก
# 597145  597146     31/7/2021  ...           ขอนแก่น               NaN
# 597146  597147     31/7/2021  ...           ขอนแก่น               NaN
# 597147  597148     31/7/2021  ...           ขอนแก่น               NaN
# 597148  597149     31/7/2021  ...           ขอนแก่น               NaN
#
# [4438 rows x 11 columns]

# %% [markdown]
# ข้อ 2 เนื่องจากไม่ให้เกิดความสับสนให้ กำหนดตัวแปร list ของแต่ละจังหวัด

# %%
list_KK = data_cases2['province_of_isolation'] == 'ขอนแก่น'

# %%
list_NK = data_cases2['province_of_isolation'] == 'นครราชสีมา'

# %%
list_UD = data_cases2['province_of_isolation'] == 'อุดรธานี'

# %%
data_cases2[list_KK | list_NK | list_UD] 
#ชี้ข้อมูลไปที่ new list และใช้เครื่องหมาย และ หรือ
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 189        190     18/3/2020  ...        นครราชสีมา             พิมาย
# 207        208     18/3/2020  ...     กรุงเทพมหานคร               NaN
# 212        213     18/3/2020  ...        นครราชสีมา       วังน้ำเขียว
# 284        285     20/3/2020  ...        นครราชสีมา   เมืองนครราชสีมา
# ...        ...           ...  ...               ...               ...
# 597149  597150     31/7/2021  ...        นครราชสีมา               NaN
# 597150  597151     31/7/2021  ...        นครราชสีมา               NaN
# 597151  597152     31/7/2021  ...        นครราชสีมา               NaN
# 597152  597153     31/7/2021  ...        นครราชสีมา               NaN
# 597153  597154     31/7/2021  ...        นครราชสีมา               NaN
#
# [13231 rows x 11 columns]

# %%
list_BK = data_cases2['province_of_onset'] == 'กรุงเทพมหานคร' #ข้อ 3

# %%
#กำหนดตัวแปร โดยชี้ไปที่คอลัมน์เพศ ในส่วนข้อมูลที่เป็นผู้หญิง
prov_fm = data_cases2['sex'] == 'หญิง' 
prov_fm
# Out:
# 0          True
# 1          True
# 2          True
# 3         False
# 4          True
#           ...
# 597226     True
# 597227     True
# 597228     True
# 597229     True
# 597230    False
# Name: sex, Length: 597231, dtype: bool

# %%
data_cases2[list_BK & prov_fm]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# 5            6     25/1/2020  ...     กรุงเทพมหานคร               NaN
# 6            7     26/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 597225  597226     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597226  597227     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597227  597228     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597228  597229     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597229  597230     31/7/2021  ...     กรุงเทพมหานคร               NaN
#
# [67354 rows x 11 columns]

# %%
blist_male = data_cases2['sex'] == 'ชาย'
blist_age = data_cases2['age'] >=18
blist_age2 = data_cases2['age'] <=22
blist_Changmai = data_cases2['province_of_isolation'] =='เชียงใหม่'

# %%
list_khonkaen_onset = data_cases2['province_of_onset'] == 'ขอนแก่น'#ข้อ 5
KK_onset = data_cases2[list_khonkaen_onset]
KK_onset
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 588503  588504     31/7/2021  ...           ขอนแก่น             ชุมแพ
# 597145  597146     31/7/2021  ...           ขอนแก่น               NaN
# 597146  597147     31/7/2021  ...           ขอนแก่น               NaN
# 597147  597148     31/7/2021  ...           ขอนแก่น               NaN
# 597148  597149     31/7/2021  ...           ขอนแก่น               NaN
#
# [3704 rows x 11 columns]

# %%
KK_onset[['age']].mean()
# Out:
# age    34.401637
# dtype: float64

# %%
# เฉลยอาจารย์
KK_cases = data_cases2['province_of_onset'] == 'ขอนแก่น'
KK_mean = data_cases2[KK_cases]['age'].mean()
KK_mean
# Out:
# 34.40163710777626

# %% [markdown]
# พบที่ขอนแก่น

# %%
data_cases2[KK_cases]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 588503  588504     31/7/2021  ...           ขอนแก่น             ชุมแพ
# 597145  597146     31/7/2021  ...           ขอนแก่น               NaN
# 597146  597147     31/7/2021  ...           ขอนแก่น               NaN
# 597147  597148     31/7/2021  ...           ขอนแก่น               NaN
# 597148  597149     31/7/2021  ...           ขอนแก่น               NaN
#
# [3704 rows x 11 columns]

# %% [markdown]
# เอาค่า mean ไปเติมตรง missing col

# %%
data_KK = data_cases2[KK_cases]
data_KK.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_KK[['age']] = data_KK[['age']].fillna(KK_mean)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_KK.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                      False
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_KK
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 588503  588504     31/7/2021  ...           ขอนแก่น             ชุมแพ
# 597145  597146     31/7/2021  ...           ขอนแก่น               NaN
# 597146  597147     31/7/2021  ...           ขอนแก่น               NaN
# 597147  597148     31/7/2021  ...           ขอนแก่น               NaN
# 597148  597149     31/7/2021  ...           ขอนแก่น               NaN
#
# [3704 rows x 11 columns]

# %% [markdown]
# เติมค่า mean แทน missing ของ เชียงใหม่

# %%
# หาค่า mean ของเชียงใหม่
CM_cases = data_cases2['province_of_onset'] == 'เชียงใหม่'
CM_mean = data_cases2[CM_cases]['age'].mean()

# เลือกมาเฉพาะ data เชียงใหม่
data_CM = data_cases2[CM_cases]

# เติมค่า mean แทน missing
data_CM[['age']] = data_CM[['age']].fillna(CM_mean)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_CM
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 16          17     31/1/2020  ...         เชียงใหม่             หางดง
# 91          92     15/3/2020  ...         เชียงใหม่            แม่ริม
# 185        186     18/3/2020  ...         เชียงใหม่          นครพิงค์
# 192        193     18/3/2020  ...         เชียงใหม่               NaN
# 252        253     19/3/2020  ...         เชียงใหม่               NaN
# ...        ...           ...  ...               ...               ...
# 578419  578420     31/7/2021  ...         เชียงใหม่    เมืองเชียงใหม่
# 578420  578421     31/7/2021  ...         เชียงใหม่    เมืองเชียงใหม่
# 578574  578575     31/7/2021  ...         เชียงใหม่            แม่ออน
# 578581  578582     31/7/2021  ...         เชียงใหม่             สารภี
# 588974  588975     31/7/2021  ...         เชียงใหม่          เวียงแหง
#
# [4411 rows x 11 columns]

# %% [markdown]
# ##ต่อตารางแนวแกน Y [PD]

# %%
data_CMKK = pd.concat([data_CM,data_KK])
data_CMKK
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 16          17     31/1/2020  ...         เชียงใหม่             หางดง
# 91          92     15/3/2020  ...         เชียงใหม่            แม่ริม
# 185        186     18/3/2020  ...         เชียงใหม่          นครพิงค์
# 192        193     18/3/2020  ...         เชียงใหม่               NaN
# 252        253     19/3/2020  ...         เชียงใหม่               NaN
# ...        ...           ...  ...               ...               ...
# 588503  588504     31/7/2021  ...           ขอนแก่น             ชุมแพ
# 597145  597146     31/7/2021  ...           ขอนแก่น               NaN
# 597146  597147     31/7/2021  ...           ขอนแก่น               NaN
# 597147  597148     31/7/2021  ...           ขอนแก่น               NaN
# 597148  597149     31/7/2021  ...           ขอนแก่น               NaN
#
# [8115 rows x 11 columns]

# %% [markdown]
# ## Handling Missing Value 5 (แทนด้วย ค่ากลางของ samples ใน class เดียวกัน)(ต่อ)

# %%
data_cases2
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 597226  597227     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597227  597228     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597228  597229     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597229  597230     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597230  597231     31/7/2021  ...     กรุงเทพมหานคร               NaN
#
# [597231 rows x 11 columns]

# %% [markdown]
# เติมค่า missing ให้จังหวัดก่อน

# %%
data_cases2[['province_of_onset']] = data_cases2[['province_of_onset']].fillna('ไม่มีข้อมูล')

# %% [markdown]
# หาจังหวัดทั้งหมด

# %%
all_cities = set(data_cases2['province_of_onset'])
all_cities
# Out:
# {'กระบี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธ์ุ',
#  'กาฬสิินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่่น',
#  'จ.ปัตตานี',
#  'จังหวัดร้อยเอ็ด',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชลบุุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชััยภูมิ',
#  'ชุมพร',
#  'ชุุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'ธารโต',
#  'นคนปฐม',
#  'นคปฐม',
#  'นครนาชสีมา',
#  'นครนายก',
#  'นครปฐม',
#  'นครประฐม',
#  'นครพนม',
#  'นครราชธสีมา',
#  'นครราชสีมา',
#  'นครศรธรรมาช',
#  'นครศรี',
#  'นครศรีธรรมราช',
#  'นครศรีธรรรมราช',
#  'นครศรีราชสีมา',
#  'นครศรีีธรรมราช',
#  'นครสวรรค์',
#  'นครสววรค์',
#  'นตรปฐม',
#  'นนทบุรี',
#  'นนทุบรี',
#  'นราธิวาส',
#  'นาราธิวาส',
#  'นาวัง',
#  'น่าน',
#  'บางกะปิ',
#  'บึงกาฬ',
#  'บึงโขงหลง',
#  'บึึงกาฬ',
#  'บุรีรัมย์',
#  'บุรีรัยม์',
#  'บ้านหลวง',
#  'ปทุมทานี',
#  'ปทุมธานี',
#  'ปทุมธานีี',
#  'ปทุุมธานี',
#  'ประจวบครีขันธ์',
#  'ประจวบคีรีขันธื',
#  'ประจวบคีรีขันธุ์',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปลายพระยา',
#  'ปัตตาน',
#  'ปัตตานี',
#  'ปัตตานี\u200b',
#  'ปัว',
#  'ปุทมธานี',
#  'พม่า',
#  'พระนครศรียุธยา',
#  'พระนครศรีอยุทธยา',
#  'พระนครศรีอยุธนา',
#  'พระนครศรีอยุธยา',
#  'พระนครศีรอยุธยา',
#  'พระนครศีอยุธยา',
#  'พระนตรศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'ภูเพียง',
#  'มหาสารคราม',
#  'มหาสารคาม',
#  'มาเลเซีย',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยานนาวา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้องกวาง',
#  'ร้อยเอ็ด',
#  'ร้อยเอ็็ด',
#  'ร้อยเอ้ด',
#  'ร้้อยเอ็ด',
#  'ลพบรี',
#  'ลพบุรี',
#  'ลพบุุรี',
#  'ลอง',
#  'ลำปาง',
#  'ลำพูน',
#  'วังชิ้น',
#  'ศรีษะเกษ',
#  'ศรีสะเกษ',
#  'ศรีีสะเกษ',
#  'ศีรษะเกษ',
#  'ศีรสะเกษ',
#  'สกลนคร',
#  'สงขขลา',
#  'สงขลา',
#  'สงขลา\u200b',
#  'สตูล',
#  'สถานที่ทำงาน',
#  'สมทรสาคร',
#  'สมุทปราการ',
#  'สมุทรปราการ',
#  'สมุทรปาการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สมุทราปราการ',
#  'สมุทราสาคร',
#  'สมุทสงคราม',
#  'สมุทสาคร',
#  'สมุุทรปราการ',
#  'สมุุทรสงคราม',
#  'สมุุทรสาคร',
#  'สมุุทสาคร',
#  'สระบุรี',
#  'สระบุุรี',
#  'สระแก้ว',
#  'สรแก้ว',
#  'สอง',
#  'สองแคว',
#  'สิงห์บุรี',
#  'สุทรปราการ',
#  'สุพรรณบุรี',
#  'สุมทรปราการ',
#  'สุมทรสาคร',
#  'สุมุทรปราการ',
#  'สุมุทรสาคร',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุุราษฎร์ธานี',
#  'สุโขทัย',
#  'สูงเม่น',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'หนองบัวลำภูู',
#  'หนองบัวลำำภู',
#  'หนองบััวลำภู',
#  'หนองม่วงไข่',
#  'อยุธยา',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุดรธานีี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุบลราขธานี',
#  'อุบลราชธานี',
#  'อุุดรธาน',
#  'อุุดรธานี',
#  'อุุตรดิตถ์',
#  'อุุทัยธานี',
#  'อ่างทอง',
#  'ูภูเก็ต',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เด่นชัย',
#  'เพชบุรี',
#  'เพชรบุรี',
#  'เพชรบูรณ์',
#  'เพรชบุรี',
#  'เพรบุรี',
#  'เมือง',
#  'เมืองน่าน',
#  'เรือ',
#  'เลย',
#  'เวียงจันทร์',
#  'เวียงสา',
#  'แพร่',
#  'แม่ฮ่องสอน',
#  'ไม่มีข้อมูล',
#  'ไม่ระบุ'}

# %%
fixed_cities = []

for city in all_cities:
    # หาค่า mean ของเชียงใหม่
    X_cases = data_cases2['province_of_onset'] == city
    X_mean = data_cases2[X_cases]['age'].mean()

    # เลือกมาเฉพาะ data เชียงใหม่
    data_X = data_cases2[X_cases]

    # เติมค่า mean แทน missing
    data_X[['age']] = data_X[['age']].fillna(X_mean)

    fixed_cities.append(data_X)


data_cases2_nomissingage = pd.concat(fixed_cities)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_cases2_nomissingage
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 426        427     22/3/2020  ...            พัทลุง           ควนขนุน
# 565        566     22/3/2020  ...            พัทลุง           ควนขนุน
# 1000      1001     26/3/2020  ...            พัทลุง             กงหรา
# 1002      1003     26/3/2020  ...            พัทลุง            ป่าบอน
# 1023      1024     26/3/2020  ...            พัทลุง          ปากพะยูน
# ...        ...           ...  ...               ...               ...
# 399906  399907     18/7/2021  ...  พระนครศรีอยุทธยา          บางปะอิน
# 323276  323277     10/7/2021  ...             ธารโต               NaN
# 273771  273772      3/7/2021  ...   จังหวัดร้อยเอ็ด           โพนทราย
# 403503  403504     19/7/2021  ...           เด่นชัย         ปงป่าหวาย
# 403504  403505     19/7/2021  ...           เด่นชัย           ห้วยไร่
#
# [597231 rows x 11 columns]

# %%
data_cases2_nomissingage.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_cases2_nomissingage[['age']] = data_cases2_nomissingage[['age']].fillna(data_cases2_nomissingage['age'].mean())

# %%
data_cases2_nomissingage.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                      False
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_cases2_nomissingage
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 426        427     22/3/2020  ...            พัทลุง           ควนขนุน
# 565        566     22/3/2020  ...            พัทลุง           ควนขนุน
# 1000      1001     26/3/2020  ...            พัทลุง             กงหรา
# 1002      1003     26/3/2020  ...            พัทลุง            ป่าบอน
# 1023      1024     26/3/2020  ...            พัทลุง          ปากพะยูน
# ...        ...           ...  ...               ...               ...
# 399906  399907     18/7/2021  ...  พระนครศรีอยุทธยา          บางปะอิน
# 323276  323277     10/7/2021  ...             ธารโต               NaN
# 273771  273772      3/7/2021  ...   จังหวัดร้อยเอ็ด           โพนทราย
# 403503  403504     19/7/2021  ...           เด่นชัย         ปงป่าหวาย
# 403504  403505     19/7/2021  ...           เด่นชัย           ห้วยไร่
#
# [597231 rows x 11 columns]

# %% [markdown]
# ##การเรียงข้อมูล[PD]

# %%
data_cases2_nomissingage.sort_values(by=['No.'])
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 597226  597227     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597227  597228     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597228  597229     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597229  597230     31/7/2021  ...     กรุงเทพมหานคร               NaN
# 597230  597231     31/7/2021  ...     กรุงเทพมหานคร               NaN
#
# [597231 rows x 11 columns]

# %% [markdown]
# ##Outlier

# %%
from matplotlib import pyplot as plt

# %%
data_dict = plt.boxplot(data_cases2_nomissingage['age'])

# %%
data_dict  # curly brackets
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f7448be72d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f7448bee690>,
#   <matplotlib.lines.Line2D at 0x7f7448beebd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7448bfb6d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7448bfb190>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f7448be7a50>,
#   <matplotlib.lines.Line2D at 0x7f7448bee150>]}

# %%
data_dict['boxes']

# %%
data_dict['boxes'][0]

# %%
data_dict['boxes'][0].get_ydata()
# Out:
# array([25., 25., 44., 44., 25.])

# %%
Q1 = data_dict['boxes'][0].get_ydata()[0]
Q1
# Out:
# 25.0

# %%
data_dict['fliers'][0].get_ydata()
# Out:
# array([ 74.,  77.,  81., ..., 109.,  83.,  87.])

# %%
data_dict['caps'][0].get_ydata()
# Out:
# array([1., 1.])

# %%
data_dict['caps'][1].get_ydata()
# Out:
# array([72., 72.])

# %%
cap1 = data_cases2_nomissingage['age'] >= data_dict['caps'][0].get_ydata()[0]
cap2 = data_cases2_nomissingage['age'] <= data_dict['caps'][1].get_ydata()[0]

data_cases2_nomissingage_nooutlier = data_cases2_nomissingage[cap1 & cap2]
data_cases2_nomissingage_nooutlier
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 426        427     22/3/2020  ...            พัทลุง           ควนขนุน
# 565        566     22/3/2020  ...            พัทลุง           ควนขนุน
# 1000      1001     26/3/2020  ...            พัทลุง             กงหรา
# 1002      1003     26/3/2020  ...            พัทลุง            ป่าบอน
# 1023      1024     26/3/2020  ...            พัทลุง          ปากพะยูน
# ...        ...           ...  ...               ...               ...
# 399906  399907     18/7/2021  ...  พระนครศรีอยุทธยา          บางปะอิน
# 323276  323277     10/7/2021  ...             ธารโต               NaN
# 273771  273772      3/7/2021  ...   จังหวัดร้อยเอ็ด           โพนทราย
# 403503  403504     19/7/2021  ...           เด่นชัย         ปงป่าหวาย
# 403504  403505     19/7/2021  ...           เด่นชัย           ห้วยไร่
#
# [586409 rows x 11 columns]

# %%
data_dict = plt.boxplot(data_cases2_nomissingage_nooutlier['age'])

# %% [markdown]
# ตัด outlier แบบ manual

# %%
data_cases2_nomissingage[data_cases2_nomissingage['province_of_onset'] != 'ลอง']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 426        427     22/3/2020  ...            พัทลุง           ควนขนุน
# 565        566     22/3/2020  ...            พัทลุง           ควนขนุน
# 1000      1001     26/3/2020  ...            พัทลุง             กงหรา
# 1002      1003     26/3/2020  ...            พัทลุง            ป่าบอน
# 1023      1024     26/3/2020  ...            พัทลุง          ปากพะยูน
# ...        ...           ...  ...               ...               ...
# 399906  399907     18/7/2021  ...  พระนครศรีอยุทธยา          บางปะอิน
# 323276  323277     10/7/2021  ...             ธารโต               NaN
# 273771  273772      3/7/2021  ...   จังหวัดร้อยเอ็ด           โพนทราย
# 403503  403504     19/7/2021  ...           เด่นชัย         ปงป่าหวาย
# 403504  403505     19/7/2021  ...           เด่นชัย           ห้วยไร่
#
# [597225 rows x 11 columns]

# %%
box_out_dict = data_cases2_nomissingage[data_cases2_nomissingage['province_of_onset'] != 'ลอง']
box_out_dict
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 426        427     22/3/2020  ...            พัทลุง           ควนขนุน
# 565        566     22/3/2020  ...            พัทลุง           ควนขนุน
# 1000      1001     26/3/2020  ...            พัทลุง             กงหรา
# 1002      1003     26/3/2020  ...            พัทลุง            ป่าบอน
# 1023      1024     26/3/2020  ...            พัทลุง          ปากพะยูน
# ...        ...           ...  ...               ...               ...
# 399906  399907     18/7/2021  ...  พระนครศรีอยุทธยา          บางปะอิน
# 323276  323277     10/7/2021  ...             ธารโต               NaN
# 273771  273772      3/7/2021  ...   จังหวัดร้อยเอ็ด           โพนทราย
# 403503  403504     19/7/2021  ...           เด่นชัย         ปงป่าหวาย
# 403504  403505     19/7/2021  ...           เด่นชัย           ห้วยไร่
#
# [597225 rows x 11 columns]

# %% [markdown]
# # Quiz 5
#
# เขียนฟังก์ชั่น คำนวณหา Q1,Q2,Q3,IQR,min,max โดยรับ input เป็น output ของ boxplot
#
#
#
# ```python
# def box_vals(box_out_dict):
#     #your codel
#     .
#     .
#     .
#     #your codex
#     return q1,q2,q3,ipr,vmin,vmax

# %%
def box_vals(box_out_dict):
    q1 = data_dict['boxes'][0].get_ydata()[0]
    q2 = data_dict['boxes'][0].get_ydata()[1]
    q3 = data_dict['boxes'][0].get_ydata()[2]
    iqr = q3-q1
    vmin = min(data_dict['boxes'][0].get_ydata())
    vmax = max(data_dict['boxes'][0].get_ydata())
    return  print(f'Q1 เท่ากับ {q1}\nQ2 เท่ากับ {q2}\nQ3 เท่ากับ {q3}\nIQR เท่ากับ {iqr}\nMin เท่ากับ {vmin}\nMax เท่ากับ {vmax}')

# %%
box_vals(box_out_dict)
# Out:
# Q1 เท่ากับ 25.0
# Q2 เท่ากับ 25.0
# Q3 เท่ากับ 44.0
# IQR เท่ากับ 19.0
# Min เท่ากับ 25.0
# Max เท่ากับ 44.0

# %%
box_vals(data_dict)
# Out:
# Q1 เท่ากับ 25.0
# Q2 เท่ากับ 25.0
# Q3 เท่ากับ 44.0
# IQR เท่ากับ 19.0
# Min เท่ากับ 25.0
# Max เท่ากับ 44.0

# %%
data_dict = plt.boxplot(data_cases2_nomissingage_nooutlier['age'],vert=False)
#กราฟก็จะเป็นแนวแกนวายแทน

# %%
data_dict['boxes'][0].get_xdata() #เกทเอ็ก อ่านค่าตามเอ็ก
# Out:
# array([25., 25., 44., 44., 25.])

# %% [markdown]
# Quiz กลุ่ม III (แก้ให้ function box vals สามารถรับ input ที่ box plot วาดแบบแนวนอนได้ (vert=False)

# %%
def box_vals(box_out_dict, vert = True):
        q1 = box_out_dict['boxes'][0].get_ydata()[0] 
        q2 = box_out_dict['medians'][0].get_ydata()[0]
        q3 = box_out_dict['boxes'][0].get_ydata()[2]
        iqr =  q3 - q1
        vmin =  box_out_dict['caps'][0].get_ydata()[0]
        vmax =  box_out_dict['caps'][1].get_ydata()[0] 
        if vert == False:
            q1 = box_out_dict['boxes'][0].get_xdata()[0]
            q2 = box_out_dict['medians'][0].get_xdata()[0]
            q3 = box_out_dict['boxes'][0].get_xdata()[2]
            iqr = q3 - q1
            vmin = box_out_dict['caps'][0].get_xdata()[0]
            vmax = box_out_dict['caps'][1].get_xdata()[0]
   
        return q1,q2,q3,iqr,vmin,vmax

# %%
box_vals(data_dict, vert=True)
box_vals(data_dict, vert=False)
# Out:
# (25.0, 35.0, 44.0, 19.0, 1.0, 72.0)
